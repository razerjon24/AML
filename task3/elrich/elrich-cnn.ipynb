# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set()
import biosppy.signals.ecg as ecg
from sklearn.preprocessing import normalize
import cv2

# %% [markdown]
# ## Input Data

# %%
sampling_rate=300

# %%
"""
Extracts heartbeats from one row of the input data
"""
def get_heartbeats(data):
    signal = data[~np.isnan(data)]
    rpeaks = ecg.christov_segmenter(signal=signal, sampling_rate=sampling_rate)
    beats = ecg.extract_heartbeats(signal=signal,rpeaks=rpeaks[0],sampling_rate=sampling_rate)
    return beats[0]

"""
Creates 128x128 image for an individual beat.
Stores it as e.g. './images/class_0/1.png'
"""
def create_image_for_beat(beat, row_num, beat_num, cat):
    filename = './images/class_{}/{}_{}.png'.format(cat, row_num, beat_num)
    fig = plt.figure()
    plt.plot(beat) 
    plt.xticks([]), plt.yticks([])
    fig.savefig('tmp.png',bbox_inches = 'tight',pad_inches=0)
    plt.close(fig)
    im_gray = cv2.imread('tmp.png', cv2.IMREAD_GRAYSCALE)
    im_gray = cv2.resize(im_gray, (128, 128), interpolation = cv2.INTER_LANCZOS4)
    if not cv2.imwrite(filename, im_gray):
        raise Exception("Could not write image")

"""
Creates 128x128 images for each beat in one row of the input data.
"""
def create_images_for_signal(signal, row_num, cat):
    beats = get_heartbeats(signal)
    for i, beat in enumerate(beats):
        create_image_for_beat(beat, row_num, i, cat)
    return len(beats)

# %%
counts = [0,0,0,0]
y_data = pd.read_csv('../data/y_train.csv').drop('id', axis=1)
chunksize = 1000
chunknum = 0
"""
Read in 1000 rows at a time and create images for each beat
"""
for chunk in pd.read_csv('../data/x_train.csv', chunksize=chunksize):
    print('\nProcessing chunk {}\n'.format(chunknum))
    x_data = chunk.drop('id', axis=1)
    for i, row in enumerate(x_data.values):
        cat = y_data.y[i]
        count = create_images_for_signal(row, cat, counts)
        print('created {} images for row {} of chunk {}'.format(count, i, chunknum))
    chunknum += 1
# Out:
# Processing chunk 0
#
# created 65 images for row 0 of chunk 0
# created 34 images for row 1 of chunk 0
# created 30 images for row 2 of chunk 0
# created 70 images for row 3 of chunk 0
# created 42 images for row 4 of chunk 0
# created 25 images for row 5 of chunk 0
# created 38 images for row 6 of chunk 0
# created 40 images for row 7 of chunk 0
# created 58 images for row 8 of chunk 0
# created 11 images for row 9 of chunk 0
# created 27 images for row 10 of chunk 0
# created 30 images for row 11 of chunk 0
# created 25 images for row 12 of chunk 0
# created 36 images for row 13 of chunk 0
# created 30 images for row 14 of chunk 0
# created 3 images for row 15 of chunk 0
# created 19 images for row 16 of chunk 0
# created 45 images for row 17 of chunk 0
# created 28 images for row 18 of chunk 0
# created 13 images for row 19 of chunk 0
# created 35 images for row 20 of chunk 0
# created 36 images for row 21 of chunk 0
# created 30 images for row 22 of chunk 0
# created 54 images for row 23 of chunk 0
# created 35 images for row 24 of chunk 0
# created 26 images for row 25 of chunk 0
# created 25 images for row 26 of chunk 0
# created 28 images for row 27 of chunk 0
# created 27 images for row 28 of chunk 0
# created 15 images for row 29 of chunk 0
# created 31 images for row 30 of chunk 0
# created 32 images for row 31 of chunk 0
# created 36 images for row 32 of chunk 0
# created 33 images for row 204 of chunk 0
# created 31 images for row 205 of chunk 0
# created 33 images for row 206 of chunk 0
# created 24 images for row 207 of chunk 0
# created 39 images for row 208 of chunk 0
# created 37 images for row 209 of chunk 0
# created 26 images for row 210 of chunk 0
# created 38 images for row 211 of chunk 0
# created 42 images for row 212 of chunk 0
# created 32 images for row 213 of chunk 0
# created 30 images for row 214 of chunk 0
# created 70 images for row 215 of chunk 0
# created 30 images for row 216 of chunk 0
# created 26 images for row 217 of chunk 0
# created 31 images for row 218 of chunk 0
# created 38 images for row 219 of chunk 0
# created 4 images for row 220 of chunk 0
# created 39 images for row 221 of chunk 0
# created 42 images for row 222 of chunk 0
# created 68 images for row 223 of chunk 0
# created 14 images for row 224 of chunk 0
# created 25 images for row 225 of chunk 0
# created 24 images for row 226 of chunk 0
# created 42 images for row 227 of chunk 0
# created 31 images for row 228 of chunk 0
# created 31 images for row 229 of chunk 0
# created 48 images for row 230 of chunk 0
# created 29 images for row 231 of chunk 0
# created 34 images for row 232 of chunk 0
# created 27 images for row 233 of chunk 0
# created 28 images for row 234 of chunk 0
# created 1 images for row 235 of chunk 0
# created 41 images for row 236 of chunk 0
# created 29 images for row 237 of chunk 0
# created 51 images for row 238 of chunk 0
# created 31 images for row 239 of chunk 0
# created 30 images for row 240 of chunk 0
# created 33 images for row 241 of chunk 0
# created 26 images for row 242 of chunk 0
# created 35 images for row 243 of chunk 0
# created 40 images for row 244 of chunk 0
# created 26 images for row 245 of chunk 0
# created 35 images for row 246 of chunk 0
# created 31 images for row 247 of chunk 0
# created 32 images for row 248 of chunk 0
# created 28 images for row 249 of chunk 0
# created 43 images for row 250 of chunk 0
# created 36 images for row 251 of chunk 0
# created 52 images for row 252 of chunk 0
# created 26 images for row 253 of chunk 0
# created 34 images for row 254 of chunk 0
# created 31 images for row 255 of chunk 0
# created 66 images for row 256 of chunk 0
# created 32 images for row 257 of chunk 0
# created 36 images for row 258 of chunk 0
# created 27 images for row 259 of chunk 0
# created 1 images for row 260 of chunk 0
# created 17 images for row 261 of chunk 0
# created 27 images for row 262 of chunk 0
# created 5 images for row 263 of chunk 0
# created 9 images for row 264 of chunk 0
# created 32 images for row 265 of chunk 0
# created 29 images for row 266 of chunk 0
# created 28 images for row 267 of chunk 0
# created 21 images for row 268 of chunk 0
# created 8 images for row 269 of chunk 0
# created 26 images for row 270 of chunk 0
# created 45 images for row 271 of chunk 0
# created 43 images for row 272 of chunk 0
# created 16 images for row 273 of chunk 0
# created 28 images for row 274 of chunk 0
# created 34 images for row 275 of chunk 0
# created 56 images for row 276 of chunk 0
# created 38 images for row 277 of chunk 0
# created 38 images for row 278 of chunk 0
# created 32 images for row 279 of chunk 0
# created 48 images for row 280 of chunk 0
# created 41 images for row 281 of chunk 0
# created 144 images for row 282 of chunk 0
# created 34 images for row 283 of chunk 0
# created 35 images for row 284 of chunk 0
# created 52 images for row 285 of chunk 0
# created 28 images for row 286 of chunk 0
# created 66 images for row 287 of chunk 0
# created 35 images for row 288 of chunk 0
# created 31 images for row 289 of chunk 0
# created 40 images for row 632 of chunk 0
# created 44 images for row 633 of chunk 0
# created 67 images for row 634 of chunk 0
# created 29 images for row 635 of chunk 0
# created 37 images for row 636 of chunk 0
# created 40 images for row 637 of chunk 0
# created 30 images for row 638 of chunk 0
# created 34 images for row 639 of chunk 0
# created 33 images for row 640 of chunk 0
# created 35 images for row 641 of chunk 0
# created 48 images for row 642 of chunk 0
# created 76 images for row 643 of chunk 0
# created 22 images for row 644 of chunk 0
# created 41 images for row 645 of chunk 0
# created 32 images for row 646 of chunk 0
# created 29 images for row 647 of chunk 0
# created 31 images for row 648 of chunk 0
# created 36 images for row 649 of chunk 0
# created 85 images for row 650 of chunk 0
# created 28 images for row 651 of chunk 0
# created 32 images for row 652 of chunk 0
# created 34 images for row 653 of chunk 0
# created 47 images for row 654 of chunk 0
# created 15 images for row 655 of chunk 0
# created 34 images for row 656 of chunk 0
# created 36 images for row 657 of chunk 0
# created 26 images for row 658 of chunk 0
# created 73 images for row 659 of chunk 0
# created 26 images for row 660 of chunk 0
# created 36 images for row 661 of chunk 0
# created 34 images for row 662 of chunk 0
# created 27 images for row 663 of chunk 0
# created 23 images for row 664 of chunk 0
# created 30 images for row 665 of chunk 0
# created 23 images for row 666 of chunk 0
# created 32 images for row 667 of chunk 0
# created 27 images for row 668 of chunk 0
# created 26 images for row 669 of chunk 0
# created 33 images for row 670 of chunk 0
# created 29 images for row 671 of chunk 0
# created 2 images for row 672 of chunk 0
# created 33 images for row 673 of chunk 0
# created 30 images for row 674 of chunk 0
# created 56 images for row 675 of chunk 0
# created 26 images for row 676 of chunk 0
# created 35 images for row 677 of chunk 0
# created 32 images for row 678 of chunk 0
# created 36 images for row 679 of chunk 0
# created 39 images for row 680 of chunk 0
# created 31 images for row 681 of chunk 0
# created 110 images for row 682 of chunk 0
# created 40 images for row 683 of chunk 0
# created 26 images for row 684 of chunk 0
# created 16 images for row 685 of chunk 0
# created 28 images for row 686 of chunk 0
# created 15 images for row 687 of chunk 0
# created 26 images for row 688 of chunk 0
# created 18 images for row 689 of chunk 0
# created 19 images for row 690 of chunk 0
# created 36 images for row 691 of chunk 0
# created 19 images for row 692 of chunk 0
# created 26 images for row 693 of chunk 0
# created 53 images for row 694 of chunk 0
# created 21 images for row 695 of chunk 0
# created 21 images for row 696 of chunk 0
# created 33 images for row 697 of chunk 0
# created 20 images for row 698 of chunk 0
# created 23 images for row 699 of chunk 0
# created 24 images for row 700 of chunk 0
# created 29 images for row 701 of chunk 0
# created 39 images for row 702 of chunk 0
# created 67 images for row 703 of chunk 0
# created 39 images for row 704 of chunk 0
# created 59 images for row 705 of chunk 0
# created 33 images for row 706 of chunk 0
# created 65 images for row 707 of chunk 0
# created 50 images for row 708 of chunk 0
# created 40 images for row 709 of chunk 0
# created 26 images for row 710 of chunk 0
# created 21 images for row 711 of chunk 0
# created 36 images for row 712 of chunk 0
# created 29 images for row 713 of chunk 0
# created 32 images for row 714 of chunk 0
# created 1 images for row 715 of chunk 0
# created 14 images for row 716 of chunk 0
# created 51 images for row 717 of chunk 0
# created 34 images for row 316 of chunk 1
# created 24 images for row 317 of chunk 1
# created 55 images for row 318 of chunk 1
# created 33 images for row 319 of chunk 1
# created 25 images for row 320 of chunk 1
# created 58 images for row 321 of chunk 1
# created 58 images for row 322 of chunk 1
# created 22 images for row 323 of chunk 1
# created 12 images for row 324 of chunk 1
# created 32 images for row 325 of chunk 1
# created 23 images for row 326 of chunk 1
# created 35 images for row 327 of chunk 1
# created 41 images for row 328 of chunk 1
# created 64 images for row 329 of chunk 1
# created 30 images for row 330 of chunk 1
# created 64 images for row 331 of chunk 1
# created 33 images for row 332 of chunk 1
# created 36 images for row 333 of chunk 1
# created 27 images for row 334 of chunk 1
# created 30 images for row 335 of chunk 1
# created 51 images for row 336 of chunk 1
# created 13 images for row 337 of chunk 1
# created 29 images for row 338 of chunk 1
# created 50 images for row 339 of chunk 1
# created 34 images for row 340 of chunk 1
# created 32 images for row 341 of chunk 1
# created 121 images for row 342 of chunk 1
# created 35 images for row 343 of chunk 1
# created 27 images for row 344 of chunk 1
# created 34 images for row 345 of chunk 1
# created 48 images for row 346 of chunk 1
# created 14 images for row 347 of chunk 1
# created 32 images for row 348 of chunk 1
# created 14 images for row 349 of chunk 1
# created 19 images for row 350 of chunk 1
# created 61 images for row 351 of chunk 1
# created 34 images for row 352 of chunk 1
# created 45 images for row 353 of chunk 1
# created 33 images for row 354 of chunk 1
# created 51 images for row 355 of chunk 1
# created 33 images for row 356 of chunk 1
# created 33 images for row 357 of chunk 1
# created 13 images for row 358 of chunk 1
# created 17 images for row 359 of chunk 1
# created 44 images for row 360 of chunk 1
# created 52 images for row 361 of chunk 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f012181c7599> in <module>
#      11     for i, row in enumerate(x_data.values):
#      12         cat = y_data.y[i]
# ---> 13         count = create_images_for_signal(row, cat, counts)
#      14         print('created {} images for row {} of chunk {}'.format(count, i, chunknum))
#      15     chunknum += 1
#
# <ipython-input-5-0416fdaa7aa8> in create_images_for_signal(signal, cat, counts)
#      30     beats = get_heartbeats(signal)
#      31     for beat in beats:
# ---> 32         create_image_for_beat(beat, cat, counts[cat])
#      33         counts[cat] += 1
#      34     return len(beats)
#
# <ipython-input-5-0416fdaa7aa8> in create_image_for_beat(beat, cat, count)
#      15     filename = './images/class_{}/{}.png'.format(cat, count)
#      16     fig = plt.figure()
# ---> 17     plt.plot(beat)
#      18     plt.xticks([]), plt.yticks([])
#      19     fig.savefig('tmp.png',bbox_inches = 'tight',pad_inches=0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2791 @docstring.copy(Axes.plot)
#    2792 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2795         is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     924     matplotlib.figure.Figure.gca : The figure's gca method.
#     925     """
# --> 926     return gcf().gca(**kwargs)
#     927
#     928
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1930
#    1931         # no axes found, so create one which spans the figure
# -> 1932         return self.add_subplot(1, 1, 1, **kwargs)
#    1933
#    1934     def sca(self, a):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      67
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#      71         # of the axis.  We need both because the axes may become smaller
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     493         self._rasterization_zorder = None
#     494         self._connected = {}  # a dict from events to (id, func)
# --> 495         self.cla()
#     496
#     497         # funcs used to format x and y - fall back on major formatters
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1043         self.containers = []
#    1044
# -> 1045         self.grid(False)  # Disable grid on init to use rcParameter
#    1046         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#    1047                   axis=rcParams['axes.grid.axis'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2785             self.xaxis.grid(b, which=which, **kwargs)
#    2786         if axis in ['y', 'both']:
# -> 2787             self.yaxis.grid(b, which=which, **kwargs)
#    2788
#    2789     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1475                 self._gridOnMajor = b
#    1476             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1477                                  **gridkw)
#    1478         self.stale = True
#    1479
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     886             # apply the new kwargs to the existing ticks
#     887             if which == 'major' or which == 'both':
# --> 888                 for tick in self.majorTicks:
#     889                     tick._apply_params(**kwtrans)
#     890             if which == 'minor' or which == 'both':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     668                 instance.majorTicks = []
#     669                 tick = instance._get_tick(major=True)
# --> 670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#     672             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     667             if self._major:
#     668                 instance.majorTicks = []
# --> 669                 tick = instance._get_tick(major=True)
#     670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2220         else:
#    2221             tick_kw = self._minor_tick_kw
# -> 2222         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2223
#    2224     def _get_label(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     581                           markersize=self._size,
#     582                           markeredgewidth=self._width,
# --> 583                           zorder=self._zorder)
#     584         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     585         self._set_artist_props(l)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in _recache(self)
#     247             return
#     248         self._path = _empty_path
# --> 249         self._transform = IdentityTransform()
#     250         self._alt_path = None
#     251         self._alt_transform = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1682
#    1683     def __init__(self, *args, **kwargs):
# -> 1684         Transform.__init__(self, *args, **kwargs)
#    1685         self._inverted = None
#    1686
#
# KeyboardInterrupt:

# %%
counts
# Out:
# [27470, 4455, 13727, 1172]

# %%
sum(counts)
# Out:
# 46824

# %%
y_data = pd.read_csv('../data/y_train.csv').drop('id', axis=1)
start_row = 1362
"""
Read in 1000 rows at a time and create images for each beat
"""
chunk = pd.read_csv('../data/X_train.csv', skiprows=range(1,start_row+1), nrows=1000)
x_data = chunk.drop('id', axis=1)
for i, row in enumerate(x_data.values):
    row_num = i + start_row
    cat = y_data.y[i]
    count = create_images_for_signal(row, row_num, cat)
    print('created {} images for row {}'.format(count, i, chunknum))
# Out:
# created 29 images for row 0
# created 83 images for row 1
# created 24 images for row 2
# created 36 images for row 3
# created 24 images for row 4
# created 36 images for row 5
# created 27 images for row 6
# created 32 images for row 7
# created 15 images for row 8
# created 30 images for row 9
# created 35 images for row 10
# created 25 images for row 11
# created 44 images for row 12
# created 70 images for row 13
# created 28 images for row 14
# created 52 images for row 15
# created 17 images for row 16
# created 27 images for row 17
# created 28 images for row 18
# created 28 images for row 19
# created 52 images for row 20
# created 24 images for row 21
# created 44 images for row 22
# created 52 images for row 23
# created 29 images for row 24
# created 36 images for row 25
# created 56 images for row 26
# created 34 images for row 27
# created 21 images for row 28
# created 17 images for row 29
# created 32 images for row 30
# created 50 images for row 31
# created 33 images for row 32
# created 35 images for row 33
# created 32 images for row 34
# created 32 images for row 35
# created 25 images for row 36
# created 25 images for row 37
# created 25 images for row 38
# created 38 images for row 39
# created 28 images for row 40
# created 31 images for row 41
# created 30 images for row 42
# created 35 images for row 43
# created 36 images for row 44
# created 51 images for row 45
# created 72 images for row 46
# created 19 images for row 47
# created 36 images for row 48
# created 33 images for row 49
# created 26 images for row 50
# created 28 images for row 51
# created 25 images for row 52
# created 23 images for row 53
# created 43 images for row 54
# created 65 images for row 55
# created 28 images for row 56
# created 32 images for row 57
# created 27 images for row 58
# created 40 images for row 59
# created 28 images for row 60
# created 25 images for row 61
# created 29 images for row 62
# created 35 images for row 63
# created 31 images for row 64
# created 12 images for row 65
# created 28 images for row 66
# created 58 images for row 67
# created 31 images for row 68
# created 1 images for row 69
# created 40 images for row 70
# created 13 images for row 71
# created 28 images for row 72
# created 53 images for row 73
# created 21 images for row 74
# created 38 images for row 75
# created 75 images for row 76
# created 24 images for row 77
# created 71 images for row 78
# created 33 images for row 79
# created 28 images for row 80
# created 29 images for row 81
# created 44 images for row 82
# created 50 images for row 83
# created 33 images for row 84
# created 30 images for row 85
# created 37 images for row 86
# created 49 images for row 87
# created 43 images for row 88
# created 28 images for row 89
# created 32 images for row 90
# created 44 images for row 91
# created 76 images for row 92
# created 18 images for row 93
# created 39 images for row 94
# created 30 images for row 95
# created 38 images for row 96
# created 24 images for row 97
# created 43 images for row 98
# created 38 images for row 99
# created 18 images for row 100
# created 29 images for row 101
# created 55 images for row 102
# created 30 images for row 103
# created 25 images for row 104
# created 89 images for row 105
# created 99 images for row 106
# created 33 images for row 107
# created 21 images for row 108
# created 37 images for row 109
# created 9 images for row 110
# created 21 images for row 111
# created 0 images for row 112
# created 56 images for row 113
# created 33 images for row 114
# created 1 images for row 115
# created 31 images for row 116
# created 38 images for row 117
# created 36 images for row 118
# created 22 images for row 259
# created 28 images for row 260
# created 66 images for row 261
# created 24 images for row 262
# created 20 images for row 263
# created 12 images for row 264
# created 32 images for row 265
# created 15 images for row 266
# created 37 images for row 267
# created 27 images for row 268
# created 107 images for row 269
# created 32 images for row 270
# created 32 images for row 271
# created 26 images for row 272
# created 25 images for row 273
# created 36 images for row 274
# created 36 images for row 275
# created 35 images for row 276
# created 59 images for row 277
# created 10 images for row 278
# created 22 images for row 279
# created 31 images for row 280
# created 7 images for row 281
# created 31 images for row 282
# created 4 images for row 283
# created 69 images for row 284
# created 33 images for row 285
# created 26 images for row 286
# created 52 images for row 287
# created 45 images for row 288
# created 34 images for row 289
# created 37 images for row 290
# created 39 images for row 291
# created 44 images for row 292
# created 23 images for row 293
# created 23 images for row 294
# created 34 images for row 295
# created 71 images for row 296
# created 26 images for row 297
# created 77 images for row 298
# created 32 images for row 299
# created 22 images for row 300
# created 39 images for row 301
# created 34 images for row 302
# created 29 images for row 303
# created 46 images for row 304
# created 23 images for row 305
# created 43 images for row 306
# created 43 images for row 307
# created 27 images for row 308
# created 15 images for row 309
# created 9 images for row 310
# created 72 images for row 311
# created 28 images for row 312
# created 30 images for row 313
# created 31 images for row 314
# created 62 images for row 315
# created 31 images for row 316
# created 45 images for row 317
# created 27 images for row 318
# created 13 images for row 319
# created 16 images for row 320
# created 34 images for row 321
# created 57 images for row 322
# created 88 images for row 323
# created 31 images for row 324
# created 35 images for row 325
# created 38 images for row 326
# created 73 images for row 327
# created 34 images for row 328
# created 42 images for row 329
# created 71 images for row 330
# created 59 images for row 331
# created 33 images for row 332
# created 29 images for row 333
# created 72 images for row 334
# created 17 images for row 335
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-607e55629ab5> in <module>
#       9     row_num = i + start_row
#      10     cat = y_data.y[i]
# ---> 11     count = create_images_for_signal(row, row_num, cat)
#      12     print('created {} images for row {}'.format(count, i, chunknum))
#
# <ipython-input-25-c80de588dc00> in create_images_for_signal(signal, row_num, cat)
#      30     beats = get_heartbeats(signal)
#      31     for i, beat in enumerate(beats):
# ---> 32         create_image_for_beat(beat, row_num, i, cat)
#      33     return len(beats)
#
# <ipython-input-25-c80de588dc00> in create_image_for_beat(beat, row_num, beat_num, cat)
#      15     filename = './images/class_{}/{}_{}.png'.format(cat, row_num, beat_num)
#      16     fig = plt.figure()
# ---> 17     plt.plot(beat)
#      18     plt.xticks([]), plt.yticks([])
#      19     fig.savefig('tmp.png',bbox_inches = 'tight',pad_inches=0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2791 @docstring.copy(Axes.plot)
#    2792 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2795         is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     924     matplotlib.figure.Figure.gca : The figure's gca method.
#     925     """
# --> 926     return gcf().gca(**kwargs)
#     927
#     928
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1930
#    1931         # no axes found, so create one which spans the figure
# -> 1932         return self.add_subplot(1, 1, 1, **kwargs)
#    1933
#    1934     def sca(self, a):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      67
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#      71         # of the axis.  We need both because the axes may become smaller
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     493         self._rasterization_zorder = None
#     494         self._connected = {}  # a dict from events to (id, func)
# --> 495         self.cla()
#     496
#     497         # funcs used to format x and y - fall back on major formatters
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1043         self.containers = []
#    1044
# -> 1045         self.grid(False)  # Disable grid on init to use rcParameter
#    1046         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#    1047                   axis=rcParams['axes.grid.axis'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2785             self.xaxis.grid(b, which=which, **kwargs)
#    2786         if axis in ['y', 'both']:
# -> 2787             self.yaxis.grid(b, which=which, **kwargs)
#    2788
#    2789     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1475                 self._gridOnMajor = b
#    1476             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1477                                  **gridkw)
#    1478         self.stale = True
#    1479
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     886             # apply the new kwargs to the existing ticks
#     887             if which == 'major' or which == 'both':
# --> 888                 for tick in self.majorTicks:
#     889                     tick._apply_params(**kwtrans)
#     890             if which == 'minor' or which == 'both':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     668                 instance.majorTicks = []
#     669                 tick = instance._get_tick(major=True)
# --> 670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#     672             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     667             if self._major:
#     668                 instance.majorTicks = []
# --> 669                 tick = instance._get_tick(major=True)
#     670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2220         else:
#    2221             tick_kw = self._minor_tick_kw
# -> 2222         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2223
#    2224     def _get_label(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     581                           markersize=self._size,
#     582                           markeredgewidth=self._width,
# --> 583                           zorder=self._zorder)
#     584         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     585         self._set_artist_props(l)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in _recache(self)
#     247             return
#     248         self._path = _empty_path
# --> 249         self._transform = IdentityTransform()
#     250         self._alt_path = None
#     251         self._alt_transform = None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1682
#    1683     def __init__(self, *args, **kwargs):
# -> 1684         Transform.__init__(self, *args, **kwargs)
#    1685         self._inverted = None
#    1686
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train model
