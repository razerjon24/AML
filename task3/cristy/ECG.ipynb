# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import biosppy as bsp
import neurokit as nk
import seaborn as sns




dataset = pd.read_csv('/Users/Cristy/Downloads/task3/X_train.csv')
labels=pd.read_csv('/Users/Cristy/Downloads/task3/y_train.csv')
dataset['labels']=pd.Series(labels['y'])
dataset=dataset.drop(columns='id')
dataset.head()
# Out:
#     x0   x1   x2   x3   x4   x5   x6   x7   x8   x9  ...  x17804  x17805  \
# 0  215  210  200  184  159  131  107   87   61   38  ...     NaN     NaN
# 1   56   53   50   47   42   38   34   30   26   23  ...     NaN     NaN
# 2  -65  -63  -61  -59  -57  -55  -52  -49  -46  -44  ...     NaN     NaN
# 3   38   67  100  131  161  191  219  249  267  275  ...     NaN     NaN
# 4 -291 -279 -261 -224 -148  -64   11   66   71   42  ...     NaN     NaN
#
#    x17806  x17807  x17808  x17809  x17810  x17811  x17812  labels
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN       1
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN       2
#
# [5 rows x 17814 columns]

# %%
dataset.shape
# Out:
# (5117, 17814)

# %%
for i in range(len(set(labels.y))):
    print(i,labels[labels['y']==i].shape[0])
# Out:
# 0 3030
# 1 443
# 2 1474
# 3 170

# %%
for i in range(len(test['templates'])):
    plt.plot(test['templates'][i])


#test['templates'][0]

# %% [markdown]
# Features:
#
#     1. Mean heart rate
#
#     2. Heart rate variability
#
#     3. Mean heart beat template
#
#     4. Median heart beat template

# %% [markdown]
# ## Class 0

# %%
x=np.array(dataset[dataset.labels==0].sample(1).drop(columns='labels'))
signal=x[~np.isnan(x)]
test0=bsp.signals.ecg.ecg(signal=signal, sampling_rate=300.0,show=True)

# %%
plt.plot(test0['filtered'][0:2500])
plt.scatter(test0['rpeaks'][0:10],test0['filtered'][test0['rpeaks']][0:10],color='red')
plt.show()

# %%
plt.plot(signal[0:2500])
plt.scatter(test0['rpeaks'][0:10],signal[test0['rpeaks']][0:10],color='red')
plt.show()

# %%
print(len(test0['templates']))
[len(test0['templates'][i]) for i in range(len(test0['templates']))]
# Out:
# 31
# [180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180]

# %%
test0
# Out:
# ReturnTuple(ts=array([0.00000000e+00, 3.33290984e-03, 6.66581968e-03, ...,
#        2.62233346e+01, 2.62266675e+01, 2.62300004e+01]), filtered=array([  8.129964  ,   9.72023719,  12.24167338, ..., -13.67567446,
#         -7.42830556,  -0.33699333]), rpeaks=array([ 170,  431,  689,  924, 1154, 1385, 1618, 1848, 2084, 2327, 2577,
#        2823, 3070, 3313, 3544, 3778, 4019, 4271, 4529, 4772, 5010, 5261,
#        5515, 5768, 6008, 6246, 6487, 6746, 7012, 7261, 7506]), templates_ts=array([-2.00000000e-01, -1.96666667e-01, -1.93333333e-01, -1.90000000e-01,
#        -1.86666667e-01, -1.83333333e-01, -1.80000000e-01, -1.76666667e-01,
#        -1.73333333e-01, -1.70000000e-01, -1.66666667e-01, -1.63333333e-01,
#        -1.60000000e-01, -1.56666667e-01, -1.53333333e-01, -1.50000000e-01,
#        -1.46666667e-01, -1.43333333e-01, -1.40000000e-01, -1.36666667e-01,
#        -1.33333333e-01, -1.30000000e-01, -1.26666667e-01, -1.23333333e-01,
# ...

# %%
plt.plot(np.mean(test0['templates'],axis=0),color='red')
plt.plot(np.median(test0['templates'],axis=0),color='blue')

# %%
print(np.mean(test0['heart_rate']),np.var(test0['heart_rate']))
# Out:
# 65.05289041726273 13.011822639416009

# %% [markdown]
# ## Class 1

# %%
x=np.array(dataset[dataset.labels==1].sample(1).drop(columns='labels'))
signal=x[~np.isnan(x)]
test1=bsp.signals.ecg.ecg(signal=signal, sampling_rate=300.0,show=True)

# %%
plt.plot(test1['filtered'][0:3000])
plt.scatter(test1['rpeaks'][0:10],test1['filtered'][test1['rpeaks']][0:10],color='red')
plt.show()

# %%
plt.plot(signal[0:3000])
plt.scatter(test1['rpeaks'][0:10],signal[test1['rpeaks']][0:10],color='red')
plt.show()

# %%
print(len(test1['templates']))
[len(test1['templates'][i]) for i in range(len(test1['templates']))]
# Out:
# 111
# [180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180]

# %%
plt.plot(np.mean(test1['templates'],axis=0),color='red')
plt.plot(np.median(test1['templates'],axis=0),color='blue')

# %%
print(np.mean(test1['heart_rate']),np.var(test1['heart_rate']))
# Out:
# 121.64957185747144 159.43861151556007

# %% [markdown]
# ## Class 2

# %%
x=np.array(dataset[dataset.labels==2].sample(1).drop(columns='labels'))
signal=x[~np.isnan(x)]
test2=bsp.signals.ecg.ecg(signal=signal, sampling_rate=300.0,show=True)

# %%
plt.plot(test2['filtered'][0:2100])
plt.scatter(test2['rpeaks'][0:10],test2['filtered'][test2['rpeaks']][0:10],color='red')
plt.show()

# %%
print(len(test2['templates']))
[len(test2['templates'][i]) for i in range(len(test2['templates']))]
# Out:
# 35
# [180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180]

# %%
plt.plot(np.mean(test2['templates'],axis=0),color='red')
plt.plot(np.median(test2['templates'],axis=0),color='blue')

# %%
print(np.mean(test2['heart_rate']),np.var(test2['heart_rate']))
# Out:
# 79.21402311907384 2.294944576358304

# %% [markdown]
# ### NeuroKit

# %%
from sklearn.externals import joblib

x=np.array(dataset[dataset.labels==2].sample(1).drop(columns='labels'))
signal=x[~np.isnan(x)]
bio2 = nk.bio_process(ecg=signal, sampling_rate=300)
# Out:
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
test2
# Out:
# ReturnTuple(ts=array([0.00000000e+00, 3.33271548e-03, 6.66543095e-03, ...,
#        1.79700019e+01, 1.79733346e+01, 1.79766673e+01]), filtered=array([ 13.64822973,  55.51164989,  90.52596101, ..., -29.52797697,
#        -23.60464876, -18.19763963]), rpeaks=array([ 103,  320,  570,  803, 1114, 1229, 1345, 1514, 1760, 2011, 2261,
#        2512, 2765, 3017, 3271, 3530, 3791, 4051, 4207, 4313, 4574, 4835,
#        4913, 5095]), templates_ts=array([-2.00000000e-01, -1.96666667e-01, -1.93333333e-01, -1.90000000e-01,
#        -1.86666667e-01, -1.83333333e-01, -1.80000000e-01, -1.76666667e-01,
#        -1.73333333e-01, -1.70000000e-01, -1.66666667e-01, -1.63333333e-01,
#        -1.60000000e-01, -1.56666667e-01, -1.53333333e-01, -1.50000000e-01,
#        -1.46666667e-01, -1.43333333e-01, -1.40000000e-01, -1.36666667e-01,
#        -1.33333333e-01, -1.30000000e-01, -1.26666667e-01, -1.23333333e-01,
#        -1.20000000e-01, -1.16666667e-01, -1.13333333e-01, -1.10000000e-01,
# ...

# %%
bio2['ECG'].keys()
# Out:
# dict_keys(['R_Peaks', 'Cardiac_Cycles', 'T_Waves', 'P_Waves', 'Q_Waves', 'S_Waves', 'Q_Waves_Onsets', 'T_Waves_Onsets', 'T_Waves_Ends', 'Probable_Lead', 'Cardiac_Cycles_Signal_Quality', 'Average_Signal_Quality', 'ECG_Signal_Quality', 'HRV'])

# %%
plt.plot(signal)

# %%
plt.plot(bio2['df'][0:1000].ECG_Filtered)
#plt.plot(signal[0:1500])
plt.scatter(bio2['ECG']['R_Peaks'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['R_Peaks']][0:3],color='blue')
plt.scatter(bio2['ECG']['Q_Waves'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['Q_Waves']][0:3],color='purple')
plt.scatter(bio2['ECG']['Q_Waves_Onsets'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['Q_Waves_Onsets']][0:3],color='black')

plt.scatter(bio2['ECG']['T_Waves'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves']][0:3],color='green')
plt.scatter(bio2['ECG']['T_Waves_Onsets'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves_Onsets']][0:3],color='red')
plt.scatter(bio2['ECG']['T_Waves_Ends'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves_Ends']][0:3],color='grey')

plt.scatter(bio2['ECG']['P_Waves'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['P_Waves']][0:3],color='orange')
plt.scatter(bio2['ECG']['S_Waves'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['S_Waves']][0:3],color='yellow')

# %%
print(len(bio2['ECG']['S_Waves'][1:]), len(bio2['ECG']['Q_Waves']))
# Out:
# 50 51

# %%
bio2['ECG']['Q_Waves']
# Out:
# [640,
#  940,
#  1256,
#  1579,
#  1887,
#  2201,
#  2520,
#  2831,
#  3140,
#  3455,
#  3778,
#  4086,
#  4400,
#  4724,
#  5053,
#  5359,
#  5675,
#  5990,
#  6315,
#  6619,
#  6930,
#  7071,
#  7529,
#  7824,
#  8105,
#  8388,
#  8671,
#  8952,
#  9225,
#  9512,
#  9813,
#  10112,
#  10414,
#  10729,
#  11042,
#  11339,
#  11647,
#  11956,
#  12250,
#  12521,
#  12793,
#  13062,
#  13335,
#  13613,
#  13898,
#  14194,
#  14482,
#  14782,
#  15086,
#  15392,
#  15701]

# %%
bio2['ECG']['S_Waves']
# Out:
# [363,
#  658,
#  963,
#  1277,
#  1602,
#  1912,
#  2223,
#  2541,
#  2849,
#  3162,
#  3477,
#  3803,
#  4108,
#  4422,
#  4749,
#  5076,
#  5380,
#  5696,
#  6012,
#  6335,
#  6640,
#  7093,
#  7551,
#  7845,
#  8126,
#  8409,
#  8693,
#  8973,
#  9247,
#  9533,
#  9834,
#  10132,
#  10436,
#  10751,
#  11062,
#  11360,
#  11669,
#  11976,
#  12270,
#  12539,
#  12815,
#  13086,
#  13357,
#  13634,
#  13919,
#  14215,
#  14503,
#  14804,
#  15108,
#  15413,
#  15721]

# %%
[x-y for x, y in zip(bio2['ECG']['S_Waves'][1:], bio2['ECG']['Q_Waves'])]
# Out:
# [18,
#  23,
#  21,
#  23,
#  25,
#  22,
#  21,
#  18,
#  22,
#  22,
#  25,
#  22,
#  22,
#  25,
#  23,
#  21,
#  21,
#  22,
#  20,
#  21,
#  163,
#  480,
#  316,
#  302,
#  304,
#  305,
#  302,
#  295,
#  308,
#  322,
#  319,
#  324,
#  337,
#  333,
#  318,
#  330,
#  329,
#  314,
#  289,
#  294,
#  293,
#  295,
#  299,
#  306,
#  317,
#  309,
#  322,
#  326,
#  327,
#  329]

# %%
# FEATURES:

#BEATS PER MINUTE
bpm=[(300/(x-y))*60 for x, y in zip(bio2['ECG']['R_Peaks'][1:], bio2['ECG']['R_Peaks'])]
# mean
bpm_avg=np.mean(bpm)
# std
bpm_std=np.std(bpm)
#median
bpm_med=np.median(bpm)
#min
bpm_min=np.min(bpm)
#max 
bpm_max=np.max(bpm)

#mean P amplitude
P_avg=np.mean(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['P_Waves']])
#std P amplitude
P_std=np.std(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['P_Waves']])

#mean Q amplitude
Q_avg=np.mean(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['Q_Waves']])
#std Q amplitude
Q_std=np.std(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['Q_Waves']])

#mean R amplitude
R_avg=np.mean(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['R_Peaks']])
#std R amplitude
R_std=np.std(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['R_Peaks']])


#mean S amplitude
S_avg=np.mean(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['S_Waves']])
#std S amplitude
S_std=np.std(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['S_Waves']])


#mean T amplitude
T_avg=np.mean(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves']])
#std T amplitude
T_std=np.std(bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves']])
# Out:
# 60.614704214312596 58.63192182410423 9.54637713551221

# %%
#np.subtract([1,2,3],[3,1,2])
#np.subtract(bio2['ECG']['T_Waves_Ends'],bio2['ECG']['Q_Waves_Onsets'])
print(len(bio2['ECG']['Q_Waves_Onsets']),len(bio2['ECG']['S_Waves']),len(bio2['ECG']['R_Peaks']))
# Out:
# 20 17 24

# %%
np.min(bio2['ECG']['T_Waves_Ends'])
# Out:
# 275

# %%
twaves_ends=[i for i in bio2['ECG']['T_Waves_Ends'] if i>np.min(bio2['ECG']['Q_Waves_Onsets'])]
qwaves_on=[i for i in bio2['ECG']['Q_Waves_Onsets'] if i<np.max(bio2['ECG']['T_Waves_Ends'])]

print(len(bio2['ECG']['T_Waves_Ends']),len(twaves_ends),len(bio2['ECG']['Q_Waves_Onsets']),len(qwaves_on))
# Out:
# 17 16 20 20

# %%
print(twaves_ends,bio2['ECG']['T_Waves_Ends'])
# Out:
# [524, 738, 1003, 1225, 1421, 1605, 1888, 2334, 2544, 2724, 2894, 3441, 3612, 3855, 4101, 4452] [275, 524, 738, 1003, 1225, 1421, 1605, 1888, 2334, 2544, 2724, 2894, 3441, 3612, 3855, 4101, 4452]

# %%
qwaves_on
# Out:
# [362,
#  615,
#  877,
#  1089,
#  1315,
#  1537,
#  1725,
#  2024,
#  2197,
#  2458,
#  2611,
#  2809,
#  2996,
#  3254,
#  3541,
#  3652,
#  3750,
#  3967,
#  4192,
#  4325]

# %% [markdown]
# ## Class 3

# %%
x=np.array(dataset[dataset.labels==3].sample(1).drop(columns='labels'))
signal=x[~np.isnan(x)]
test3=bsp.signals.ecg.ecg(signal=signal, sampling_rate=300.0,show=True)

# %%
plt.plot(test3['filtered'][0:2000])
plt.scatter(test3['rpeaks'][0:10],test3['filtered'][test3['rpeaks']][0:10],color='red')
plt.show()

# %%
print(len(test3['templates']))
[len(test3['templates'][i]) for i in range(len(test3['templates']))]
# Out:
# 34
# [180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180,
#  180]

# %%
plt.plot(np.mean(test3['templates'],axis=0),color='red')
plt.plot(np.median(test3['templates'],axis=0),color='blue')

# %%
print(np.mean(test3['heart_rate']),np.var(test3['heart_rate']))
# Out:
# 93.026951732021 186.49215335523238

# %% [markdown]
# ## Running NeuroKit example code

# %%
#https://raw.githubusercontent.com/neuropsychology/NeuroKit.py/master/examples/Bio/bio_100Hz.csv
    
    
    
url = 'https://raw.githubusercontent.com/neuropsychology/NeuroKit.py/master/examples/Bio/bio_100Hz.csv'
df = pd.read_csv(url)
print(df.head(5))
# Out:
#         ECG        EDA  Photosensor       RSP
# 0 -0.015869  13.196868          5.0  0.778931
# 1 -0.011703  13.197173          5.0  0.777588
# 2 -0.009766  13.197020          5.0  0.777435
# 3 -0.013321  13.197631          5.0  0.777557
# 4 -0.009583  13.196715          5.0  0.775299

# %%
import matplotlib
# Plotting preferences
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [14.0, 10.0]  # Bigger figures
sns.set_style("whitegrid")  # White background
sns.set_palette(sns.color_palette("hls"))  # Better colours

# %%
df.plot()

# %%
import sklearn.externals.joblib
# Process the signals
bio = nk.bio_process(ecg=df["ECG"], rsp=df["RSP"], eda=df["EDA"], add=df["Photosensor"], sampling_rate=100)
# Plot the processed dataframe, normalizing all variables for viewing purpose
nk.z_score(bio["df"]).plot()
# Out:
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
bio['ECG']
# Out:
# {'R_Peaks': array([   49,   147,   246,   348,   443,   531,   623,   720,   821,
#           911,  1012,  1119,  1227,  1328,  1441,  1556,  1659,  1762,
#          1861,  1951,  2053,  2158,  2253,  2350,  2449,  2548,  2648,
#          2758,  2857,  2955,  3054,  3146,  3239,  3338,  3439,  3531,
#          3629,  3726,  3818,  3915,  4014,  4107,  4201,  4294,  4381,
#          4464,  4546,  4624,  4702,  4801,  4891,  4987,  5089,  5191,
#          5285,  5384,  5485,  5578,  5674,  5774,  5872,  5975,  6086,
#          6183,  6284,  6385,  6476,  6568,  6663,  6747,  6826,  6909,
#          6992,  7080,  7171,  7268,  7368,  7457,  7550,  7644,  7734,
#          7819,  7907,  7996,  8086,  8178,  8283,  8383,  8479,  8586,
#          8696,  8794,  8904,  9013,  9113,  9221,  9331,  9429,  9532,
#          9639,  9738,  9839,  9948, 10053, 10149, 10256, 10363, 10456,
#         10563, 10679, 10774, 10891, 10999, 11102, 11211, 11314, 11410,
# ...

# %%
pd.DataFrame(bio["ECG"]["Cardiac_Cycles"]).plot(legend=False)

# %%
bio['ECG'].keys()
# Out:
# dict_keys(['R_Peaks', 'Cardiac_Cycles', 'T_Waves', 'P_Waves', 'Q_Waves', 'S_Waves', 'Q_Waves_Onsets', 'T_Waves_Onsets', 'T_Waves_Ends', 'Probable_Lead', 'Cardiac_Cycles_Signal_Quality', 'Average_Signal_Quality', 'ECG_Signal_Quality', 'HRV', 'RSA'])

# %%
bio['ECG']['HRV']
# Out:
# {'n_Artifacts': 0.006622516556291391, 'RR_Intervals': 0       980.0
#  1       990.0
#  2      1020.0
#  3       950.0
#  4       880.0
#          ...
#  146     980.0
#  147     990.0
#  148     960.0
#  149    1000.0
#  150    1060.0
#  Length: 150, dtype: float64, 'RMSSD': 72.20403602841012, 'meanNN': 985.8666666666667, 'sdNN': 85.22521814349473, 'cvNN': 0.08644700244471334, 'CVSD': 0.07323914933906896, 'medianNN': 990.0, 'madNN': 60.0, 'mcvNN': 0.06060606060606061, 'pNN50': 44.666666666666664, 'pNN20': 72.0, 'Triang': 21134.73801148973, 'Shannon_h': 5.614709844115208, 'ULF': 0.0, 'VLF': 202356.72103294055, 'LF': 298482.5121861052, 'HF': 140170.74477117858, 'VHF': 6215.945127700643, 'Total_Power': 729584.2162742498, 'LFn': 0.6804520596895318, 'HFn': 0.3195479403104682, 'LF/HF': 2.12942089073838, 'LF/P': 0.4091131709377687, 'HF/P': 0.19212414638982345}

# %% [markdown]
# # Manual feature extraction
#
# Features:
#
#     1. Average BPM
#     2. Median BPM
#     3. BPM standard dev
#     4. Minimum BPM
#     5. Maximum BPM
#     6. Mean (P,Q,R,S,T) amplitude
#     7. Std (P,Q,R,S,T) amplitude

# %% [markdown]
# $RR \quad \text{interval} \rightarrow \text{seconds per beat}$
#
# $HR= \frac{1}{RR} \rightarrow \text{beats per second}$

# %%
def extract_features(row):
    # remove NA's (extract ECG's original length)
    signal=row[~np.isnan(row)]
    bio = nk.bio_process(ecg=signal, sampling_rate=300)
    # FEATURES:

    #BEATS PER MINUTE normal--> 60-100 bpm
    bpm=[(300/(x-y))*60 for x, y in zip(bio['ECG']['R_Peaks'][1:], bio['ECG']['R_Peaks'])]
    # mean
    bpm_avg=np.mean(bpm)
    # std
    bpm_std=np.std(bpm)
    #median
    bpm_med=np.median(bpm)
    #min
    bpm_min=np.min(bpm)
    #max 
    bpm_max=np.max(bpm)

    #mean P amplitude
    P_avg=np.mean(bio['df'].ECG_Filtered.iloc[bio['ECG']['P_Waves']])
    #std P amplitude
    P_std=np.std(bio['df'].ECG_Filtered.iloc[bio['ECG']['P_Waves']])

    #mean Q amplitude
    Q_avg=np.mean(bio['df'].ECG_Filtered.iloc[bio['ECG']['Q_Waves']])
    #std Q amplitude
    Q_std=np.std(bio['df'].ECG_Filtered.iloc[bio['ECG']['Q_Waves']])

    #mean R amplitude
    R_avg=np.mean(bio['df'].ECG_Filtered.iloc[bio['ECG']['R_Peaks']])
    #std R amplitude
    R_std=np.std(bio['df'].ECG_Filtered.iloc[bio['ECG']['R_Peaks']])


    #mean S amplitude
    S_avg=np.mean(bio['df'].ECG_Filtered.iloc[bio['ECG']['S_Waves']])
    #std S amplitude
    S_std=np.std(bio['df'].ECG_Filtered.iloc[bio['ECG']['S_Waves']])


    #mean T amplitude
    T_avg=np.mean(bio['df'].ECG_Filtered.iloc[bio['ECG']['T_Waves']])
    #std T amplitude
    T_std=np.std(bio['df'].ECG_Filtered.iloc[bio['ECG']['T_Waves']])
    return({'bpm_avg':bpm_avg,'bpm_std':bpm_std,'bpm_med':bpm_med,'bpm_min':bpm_min,'bpm_max':bpm_max,'P_avg':P_avg,'P_std':P_std,'Q_avg':Q_avg,'Q_std':Q_std,'R_avg':R_avg,'R_std':R_std,'S_avg':S_avg,'S_std':S_std,'T_avg':T_avg,'T_std':T_std
    })

# %%
feats=extract_features(np.array(dataset.sample(1).drop(columns='labels')))
feats
# Out:
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#     Using multitaper spectrum estimation with 7 DPSS windows
# {'bpm_avg': 71.00677584273937,
#  'bpm_std': 2.057474163663698,
#  'bpm_med': 71.42857142857143,
#  'bpm_min': 63.38028169014084,
#  'bpm_max': 75.63025210084034,
#  'P_avg': 64.13091709838619,
#  'P_std': 9.011626708134498,
#  'Q_avg': -184.55556606200034,
#  'Q_std': 22.758150720456676,
#  'R_avg': 862.0536068022849,
#  'R_std': 42.26244691908181,
# ...

# %%
feats.keys()
# Out:
# dict_keys(['bpm_avg', 'bpm_std', 'bpm_med', 'bpm_min', 'bpm_max', 'P_avg', 'P_std', 'Q_avg', 'Q_std', 'R_avg', 'R_std', 'S_avg', 'S_std', 'T_avg', 'T_std'])

# %%
dataset.head()
# Out:
#     x0   x1   x2   x3   x4   x5   x6   x7   x8   x9  ...  x17804  x17805  \
# 0  215  210  200  184  159  131  107   87   61   38  ...     NaN     NaN
# 1   56   53   50   47   42   38   34   30   26   23  ...     NaN     NaN
# 2  -65  -63  -61  -59  -57  -55  -52  -49  -46  -44  ...     NaN     NaN
# 3   38   67  100  131  161  191  219  249  267  275  ...     NaN     NaN
# 4 -291 -279 -261 -224 -148  -64   11   66   71   42  ...     NaN     NaN
#
#    x17806  x17807  x17808  x17809  x17810  x17811  x17812  labels
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN       0
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN       1
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN       2
#
# [5 rows x 17814 columns]

# %%
dataset.iloc[1]
# Out:
# x0        56.0
# x1        53.0
# x2        50.0
# x3        47.0
# x4        42.0
#           ...
# x17809     NaN
# x17810     NaN
# x17811     NaN
# x17812     NaN
# labels     0.0
# Name: 1, Length: 17814, dtype: float64

# %%
dataset.shape[0]
# Out:
# 5117

# %%
# ?range

# %%
for i in range(36,40):
    print(i)
# Out:
# 36
# 37
# 38
# 39

# %%
#bpm_av=[]
#bpm_sd=[]  
#bpm_md=[]  
#bpm_mn=[]  
#bpm_mx=[]  
#P_av=[] 
#P_sd=[] 
#Q_av=[] 
#Q_sd=[] 
#R_av=[] 
#R_sd=[] 
#S_av=[] 
#S_sd=[] 
#T_av=[] 
#T_sd=[] 
    

for i in range(4702,dataset.shape[0]):
    row=dataset.iloc[i]
    feats=extract_features(np.array(row.drop(columns='labels')))
    bpm_av.append(feats['bpm_avg'])
    bpm_sd.append(feats['bpm_std'])  
    bpm_md.append(feats['bpm_med']) 
    bpm_mn.append(feats['bpm_min'])  
    bpm_mx.append(feats['bpm_max'])  
    P_av.append(feats['P_avg']) 
    P_sd.append(feats['P_std']) 
    Q_av.append(feats['Q_avg']) 
    Q_sd.append(feats['Q_std']) 
    R_av.append(feats['R_avg']) 
    R_sd.append(feats['R_std']) 
    S_av.append(feats['S_avg'])
    S_sd.append(feats['S_std']) 
    T_av.append(feats['T_avg']) 
    T_sd.append(feats['T_std'])
    print(i)
# Out:
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#     Using multitaper spectrum estimation with 7 DPSS windows
# 4702
#     Using multitaper spectrum estimation with 7 DPSS windows
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
## Errors indexes: 628,3500,3720,4701

# %%
print(len(T_sd),len(R_sd),len(S_sd),len(Q_sd),len(P_sd),len(T_av),len(P_av),len(R_av))

#row=dataset.iloc[3500]
#extract_features(np.array(row.drop(columns='labels')))
# Out:
# 3718 3718 3718 3718 3718 3718 3718 3718

# %%
row=np.array(dataset.iloc[628])
signal=row[~np.isnan(row)]
len(signal)
plt.plot(signal)

# %%
new_df=pd.DataFrame({'bpm_avg':pd.Series(bpm_av),'bpm_sd':pd.Series(bpm_sd),'bpm_med':pd.Series(bpm_md),\
              'bpm_mn':pd.Series(bpm_mn),'bpm_max':pd.Series(bpm_mx),\
              'P_avg':pd.Series(P_av),'P_std':pd.Series(P_sd),'Q_avg':pd.Series(Q_av),'Q_std':pd.Series(Q_sd),\
              'R_avg':pd.Series(R_av),'R_std':pd.Series(R_sd),'S_avg':pd.Series(S_av),'S_std':pd.Series(S_sd),\
              'T_avg':pd.Series(T_av),'T_std':pd.Series(T_sd)})

# %%
new_df.head()
# Out:
#       bpm_avg     bpm_sd     bpm_med     bpm_mn     bpm_max      P_avg  \
# 0   75.134480  14.418661   72.144578  70.312500  183.673469  42.055355
# 1   76.629904   4.276275   75.630252  70.038911   86.538462  38.988388
# 2   66.879360   2.598394   66.176471  60.606061   71.713147  51.340678
# 3  149.471534  20.568079  156.521739  88.235294  178.217822  71.908854
# 4  103.377102  27.259630  100.000000  81.447964  272.727273  50.699500
#
#        P_std       Q_avg      Q_std       R_avg      R_std       S_avg  \
# 0  19.508386  -95.775181  20.575985  440.839247  57.688388  -67.347815
# 1  23.635195  -51.698784  12.933309  229.019804  37.562350 -176.809943
# 2  14.150140 -117.876273  10.501732  835.287639  38.599268 -432.507081
# 3  32.945851  -85.696310  24.293580  639.266906  48.815281 -525.464182
# 4  22.645343  -47.464007  21.556019  372.331508  72.717132 -400.685957
#
#        S_std       T_avg      T_std
# 0  27.902878  108.621161  15.268105
# 1  29.166433   60.619330  16.272724
# ...

# %%
labels.head()
# Out:
#    id  y
# 0   0  0
# 1   1  0
# 2   2  0
# 3   3  1
# 4   4  2

# %%
labels_new=labels[~labels.id.isin([628,3500,3720,4701])]
labels_new.iloc[3500]
# Out:
# id    3502
# y        0
# Name: 3502, dtype: int64

# %%
labels_new.reset_index(drop=True,inplace=True)
#labels_new.drop(columns='index')
labels_new.iloc[626:630]
# Out:
#       id  y
# 626  626  0
# 627  627  0
# 628  629  0
# 629  630  0

# %%
labels_new.columns
# Out:
# Index(['index', 'id', 'y'], dtype='object')

# %%
print(dataset.shape[0],len(labels_new))
idx=list(range(len(labels_new)))
# Out:
# 5117 5113

# %%
new_df['labels']=pd.Series(labels_new['y'])

# %%
new_df.head()
# Out:
#       bpm_avg     bpm_sd     bpm_med     bpm_mn     bpm_max      P_avg  \
# 0   75.134480  14.418661   72.144578  70.312500  183.673469  42.055355
# 1   76.629904   4.276275   75.630252  70.038911   86.538462  38.988388
# 2   66.879360   2.598394   66.176471  60.606061   71.713147  51.340678
# 3  149.471534  20.568079  156.521739  88.235294  178.217822  71.908854
# 4  103.377102  27.259630  100.000000  81.447964  272.727273  50.699500
#
#        P_std       Q_avg      Q_std       R_avg      R_std       S_avg  \
# 0  19.508386  -95.775181  20.575985  440.839247  57.688388  -67.347815
# 1  23.635195  -51.698784  12.933309  229.019804  37.562350 -176.809943
# 2  14.150140 -117.876273  10.501732  835.287639  38.599268 -432.507081
# 3  32.945851  -85.696310  24.293580  639.266906  48.815281 -525.464182
# 4  22.645343  -47.464007  21.556019  372.331508  72.717132 -400.685957
#
#        S_std       T_avg      T_std  labels
# 0  27.902878  108.621161  15.268105     0.0
# ...

# %%
new_df.groupby('labels').describe()
# Out:
#        bpm_avg                                                         \
#          count       mean        std        min        25%        50%
# labels
# 0.0     3027.0  78.153915  20.767650  35.737408  65.438555  74.319145
# 1.0      443.0  80.740673  23.872373  42.357930  65.541652  75.199479
# 2.0     1469.0  79.451066  27.171009  40.035971  65.331480  74.550464
# 3.0      170.0  80.333246  22.522766  41.214955  66.464389  75.487015
#
#                                bpm_sd             ...       T_avg  \
#               75%         max   count       mean  ...         75%
# labels                                            ...
# 0.0     85.748289  372.754663  3027.0  14.412676  ...  115.115068
# 1.0     88.135767  207.653197   443.0  18.236497  ...  112.986356
# 2.0     87.451478  586.751591  1469.0  18.918848  ...  109.818615
# 3.0     88.084428  179.424002   170.0  18.445455  ...  122.712198
#
#                       T_std                                             \
# ...

# %%
new_df[new_df.labels==0].describe()
# Out:
#            bpm_avg       bpm_sd      bpm_med       bpm_mn       bpm_max  \
# count  3027.000000  3027.000000  3027.000000  3027.000000   3027.000000
# mean     78.153915    14.412676    75.309150    61.684815    135.680805
# std      20.767650    44.348822    19.252636    15.868063    385.631830
# min      35.737408     0.142287    31.858407     5.459509     44.444444
# 25%      65.438555     2.224682    63.492261    52.173913     74.074074
# 50%      74.319145     5.317878    71.713147    61.433447     90.452261
# 75%      85.748289    19.127487    82.568807    70.312500    142.857143
# max     372.754663  1812.522001   214.285714   180.000000  18000.000000
#
#              P_avg        P_std        Q_avg        Q_std        R_avg  \
# count  3027.000000  3027.000000  3027.000000  3027.000000  3027.000000
# mean     64.586117    37.052269  -176.741227    53.686639   563.928112
# std      58.249880    56.276470   166.207008    79.970289   287.114632
# ...

# %%
new_df[new_df.labels==1].describe()
# Out:
#           bpm_avg      bpm_sd     bpm_med      bpm_mn      bpm_max  \
# count  443.000000  443.000000  443.000000  443.000000   443.000000
# mean    80.740673   18.236497   77.217803   61.197149   153.216016
# std     23.872373   51.414630   21.318680   16.748592   322.985064
# min     42.357930    0.188318   39.560440   17.441860    47.244094
# 25%     65.541652    2.913673   63.944170   51.873199    76.923077
# 50%     75.199479    8.047657   72.874494   60.402685    97.297297
# 75%     88.135767   19.889908   83.720930   69.767442   149.380165
# max    207.653197  716.558892  209.302326  200.000000  4500.000000
#
#             P_avg       P_std       Q_avg       Q_std        R_avg  \
# count  443.000000  443.000000  443.000000  443.000000   443.000000
# mean    60.088550   36.029142 -169.292421   51.155862   558.055245
# std     40.606837   48.987622  151.667439   67.259549   283.253368
# min      3.336030    1.459566 -981.692961    3.048952    16.769406
# ...

# %%
new_df[new_df.labels==2].describe()
# Out:
#            bpm_avg       bpm_sd      bpm_med       bpm_mn       bpm_max  \
# count  1469.000000  1469.000000  1469.000000  1469.000000   1469.000000
# mean     79.451066    18.918848    75.753192    61.262406    159.222761
# std      27.171009   105.380587    19.879568    16.785848    680.544097
# min      40.035971     0.160038    38.054968     7.456504     43.165468
# 25%      65.331480     2.412660    62.937063    50.847458     76.271186
# 50%      74.550464     6.410546    71.429696    60.402685     95.744681
# 75%      87.451478    19.645777    82.759058    70.866142    148.760331
# max     586.751591  2825.576395   183.673469   162.162162  18000.000000
#
#              P_avg        P_std        Q_avg        Q_std        R_avg  \
# count  1469.000000  1469.000000  1469.000000  1469.000000  1469.000000
# mean     66.194460    38.515704  -185.207478    54.014665   557.213897
# std      60.963464    68.039713   170.851402    81.429919   290.386577
# ...

# %%
new_df[new_df.labels==3].describe()
# Out:
#           bpm_avg      bpm_sd     bpm_med      bpm_mn      bpm_max  \
# count  170.000000  170.000000  170.000000  170.000000   170.000000
# mean    80.333246   18.445455   75.923962   60.627708   147.812322
# std     22.522766   29.759574   21.636297   15.785444   166.519539
# min     41.214955    0.541736   40.449642   28.892456    49.723757
# 25%     66.464389    2.375965   63.047868   50.349947    76.677578
# 50%     75.487015    6.798466   71.076219   59.504295    97.308670
# 75%     88.084428   26.036280   81.221147   68.965517   169.414565
# max    179.424002  261.500039  187.500000  138.461538  1636.363636
#
#             P_avg       P_std       Q_avg       Q_std        R_avg  \
# count  170.000000  170.000000  170.000000  170.000000   170.000000
# mean    69.074695   49.027819 -158.923341   61.122888   557.872256
# std     58.053196   80.336959  118.082568   94.815347   276.298536
# min      5.266341    0.993743 -703.334878    3.170046    52.867777
# ...

# %% [markdown]
# ## Classification

# %%
from sklearn.metrics import f1_score
#F1 = f1_score(y_true, y_pred, average='micro')


# Get balanced accuracy score
def score(true, pred):
    return f1_score(true, pred, average='micro')

# Oversample using SMOTE
def oversample(x_data, y_data):
    smote = SMOTE(ratio='not majority', random_state=42)
    return smote.fit_sample(x_data, y_data)

# Oversample and fit model for a CV split
def run_fold(x_train, y_train, x_test, y_test, model):
    # Oversample data
    #x_train_sm, y_train_sm = oversample(x_train, y_train)
    x_train_sm, y_train_sm = x_train, y_train
    # Fit model
    model.fit(x_train_sm, y_train_sm)
    y_train_pred = model.predict(x_train_sm)
    train_score = score(y_train_sm, y_train_pred)
    y_test_pred = model.predict(x_test)
    test_score = score(y_test, y_test_pred)
    return test_score, train_score

def cross_validate(x_data, y_data, model, variable):
    # Split data into folds
    n_splits = 10
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    folds = kf.split(x_data)
    test_scores = []
    train_scores = []
    times = []
    split = 0
    for train_index, test_index in folds:
        split += 1
        #print('Running split {}/{}'.format(split, n_splits))
        x_train = x_data[train_index]
        y_train = y_data[train_index]
        x_test = x_data[test_index]
        y_test = y_data[test_index]
        start_time = time.time()
        test_score, train_score = run_fold(x_train, y_train, x_test, y_test, model)
        end_time = time.time()
        total_time = round(end_time-start_time, ndigits=0)
        test_scores.append(test_score)
        train_scores.append(train_score)
        times.append(end_time-start_time)
        #print('Test score = {}\nTrain score = {}\nTime = {}s\n'.format(test_score, train_score, total_time))
    print('Average test score: {}\nAverage train score: {}\nTotal time: {}s'.format(np.mean(test_scores), np.mean(train_scores), np.sum(times)))
    return test_scores, train_scores, times




def cross_validate_pca(x_data, y_data, model, i):
    # Split data into folds
    n_splits = 10
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    folds = kf.split(x_data)
    test_scores = []
    train_scores = []
    times = []
    split = 0
    for train_index, test_index in folds:
        split += 1
        #print('Running split {}/{}'.format(split, n_splits))
        x_train = x_data[train_index]
        y_train = y_data[train_index]
        x_test = x_data[test_index]
        y_test = y_data[test_index]
        pca = PCA(n_components = np.round(i,2))
        pca.fit(pd.DataFrame(x_train)) 
        x_train_ = pd.DataFrame(pca.transform(x_train))
        x_test_ = pd.DataFrame(pca.transform(x_test))
        start_time = time.time()
        test_score, train_score = run_fold(x_train_, y_train, x_test_, y_test, model)
        end_time = time.time()
        total_time = round(end_time-start_time, ndigits=0)
        test_scores.append(test_score)
        train_scores.append(train_score)
        times.append(end_time-start_time)
        #print('Test score = {}\nTrain score = {}\nTime = {}s\n'.format(test_score, train_score, total_time))
    print('Average test score: {}\nAverage train score: {}\nTotal time: {}s'.format(np.mean(test_scores), np.mean(train_scores), np.sum(times)))
    return test_scores, train_scores, times


def scores_pca(tr,y,clf):
    test_scores = list()
    train_scores = list()
    times_iters = list()
    for i in np.arange(0.7,0.9,0.01,dtype=float):
        print('Start of {}'.format(np.round(i,2)))
        test_scores, train_scores, times = cross_validate_pca(tr.values, y.ravel(), clf, i)
        test_scores.append(np.mean(test_scores))
        train_scores.append(np.mean(train_scores))
        times_iters.append(np.sum(times))
        print('End of {}, time: {}s'.format(np.round(i,2),np.sum(times)))
    return test_scores, train_scores, times_iters

# %%
new_df.head()
# Out:
#       bpm_avg     bpm_sd     bpm_med     bpm_mn     bpm_max      P_avg  \
# 0   75.134480  14.418661   72.144578  70.312500  183.673469  42.055355
# 1   76.629904   4.276275   75.630252  70.038911   86.538462  38.988388
# 2   66.879360   2.598394   66.176471  60.606061   71.713147  51.340678
# 3  149.471534  20.568079  156.521739  88.235294  178.217822  71.908854
# 4  103.377102  27.259630  100.000000  81.447964  272.727273  50.699500
#
#        P_std       Q_avg      Q_std       R_avg      R_std       S_avg  \
# 0  19.508386  -95.775181  20.575985  440.839247  57.688388  -67.347815
# 1  23.635195  -51.698784  12.933309  229.019804  37.562350 -176.809943
# 2  14.150140 -117.876273  10.501732  835.287639  38.599268 -432.507081
# 3  32.945851  -85.696310  24.293580  639.266906  48.815281 -525.464182
# 4  22.645343  -47.464007  21.556019  372.331508  72.717132 -400.685957
#
#        S_std       T_avg      T_std  labels
# 0  27.902878  108.621161  15.268105     0.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn import svm
import time
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

train = new_df.drop(columns=['labels','S_avg','S_std','T_avg','T_std'])
#test = pd.read_csv("../data/X_test.csv").drop('id', axis=1)
y = new_df.labels

scaler =StandardScaler().fit(train)
train_ = scaler.transform(train)
train_ = pd.DataFrame(train_, columns=train.columns)
#test_ = scaler.transform(test)
#test_ = pd.DataFrame(test_, columns=train.columns)
train_.head()
# Out:
#     bpm_avg    bpm_sd   bpm_med    bpm_mn   bpm_max     P_avg     P_std  \
# 0 -0.159364 -0.025701 -0.176385  0.544653  0.081863 -0.394107 -0.303369
# 1 -0.094657 -0.175001  0.000587  0.527767 -0.120222 -0.447233 -0.234881
# 2 -0.516563 -0.199700 -0.479393 -0.054433 -0.151066 -0.233267 -0.392294
# 3  3.057199  0.064822  4.107539  1.650858  0.070513  0.123013 -0.080363
# 4  1.062694  0.163324  1.237866  1.231940  0.267136 -0.244374 -0.251309
#
#       Q_avg     Q_std     R_avg     R_std
# 0  0.497845 -0.415750 -0.419638 -0.127324
# 1  0.765022 -0.511432 -1.157214 -0.469115
# 2  0.363875 -0.541875  0.953870 -0.451506
# 3  0.558940 -0.369208  0.271307 -0.278012
# 4  0.790692 -0.403480 -0.658189  0.127903

# %%
clf = svm.SVC(gamma = 'scale' ,kernel = 'rbf', decision_function_shape='ovo', cache_size=3000, random_state = 42, class_weight = 'balanced')

# %%
test_scores, train_scores, times_iters = scores_pca(train_,y,clf)
# Out:
# Start of 0.7
# Average test score: 0.6057045774217222
# Average train score: 0.6204450858660151
# Total time: 13.77331829071045s
# End of 0.7, time: 13.77331829071045s
# Start of 0.71
# Average test score: 0.6115754189090021
# Average train score: 0.6269422610072579
# Total time: 13.216238975524902s
# End of 0.71, time: 13.216238975524902s
# Start of 0.72
# Average test score: 0.6115754189090021
# Average train score: 0.6269422610072579
# Total time: 13.251003980636597s
# End of 0.72, time: 13.251003980636597s
# Start of 0.73
# Average test score: 0.6115754189090021
# Average train score: 0.6269422610072579
# Total time: 13.583986520767212s
# End of 0.73, time: 13.583986520767212s
# Start of 0.74
# Average test score: 0.6115754189090021
# Average train score: 0.6269422610072579
# Total time: 13.18666386604309s
# End of 0.74, time: 13.18666386604309s
# Start of 0.75
# Average test score: 0.6115754189090021
# Average train score: 0.6269422610072579
# Total time: 13.17403244972229s
# ...

# %%
C1 = [np.round(i,4) for i in np.arange(0.101,0.103,0.0001)]
pipe_steps1 = [('scaler', StandardScaler()), ('SVM', svm.SVC(kernel = 'poly', gamma='scale',
                                                                decision_function_shape='ovo',
                                                                cache_size=3000, random_state = 42,
                                                                class_weight = 'balanced'))]
pipeline1 = Pipeline(pipe_steps1)

check_params1 = {
    'SVM__C': C1,
    'SVM__degree': [3],
    'SVM__coef0': [1]
    #'SVM__gamma':np.logspace(-9, -3, 6)
}

# %%
create_grid=GridSearchCV(pipeline1, check_params1,cv=8, scoring='f1_micro', n_jobs=-1, verbose=2)
create_grid.fit(train,y)
print("Best fit")
#print(cross_values.mean())
#print(cross_values)
print(create_grid.best_params_)
print(create_grid.best_score_)
# Out:
# Fitting 8 folds for each of 20 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:  1.1min finished
# Best fit
# {'SVM__C': 0.101, 'SVM__coef0': 1, 'SVM__degree': 3}
# 0.6841384705652259

# %%
pipe_steps2 = [('scaler', MinMaxScaler()), ('pca',PCA()), ('SVM', svm.SVC(kernel = 'rbf', gamma='scale',
                                                                decision_function_shape='ovo',
                                                                cache_size=3000, random_state = 42,
                                                                class_weight = 'balanced'))]
pipeline2 = Pipeline(pipe_steps2)

check_params2 = {
    'pca__n_components':[0.9],
    'SVM__C': C1
    #'SVM__gamma':np.logspace(-9, -3, 6)
}

# %%
create_grid=GridSearchCV(pipeline2, check_params2,cv=8, scoring='f1_micro', n_jobs=-1, verbose=2)
create_grid.fit(train,y)
print("Best fit")
#print(cross_values.mean())
#print(cross_values)
print(create_grid.best_params_)
print(create_grid.best_score_)
# Out:
# Fitting 8 folds for each of 20 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:  1.3min finished
# Best fit
# {'SVM__C': 0.1026, 'pca__n_components': 0.9}
# 0.6352434969685117

# %%
pipe_steps3 = [('scaler', MinMaxScaler()), ('SVM', svm.SVC(kernel = 'rbf', gamma='scale',
                                                                decision_function_shape='ovo',
                                                                cache_size=3000, random_state = 42,
                                                                class_weight = 'balanced'))]
pipeline3 = Pipeline(pipe_steps3)

check_params3 = {
    'SVM__C': C1
    #'SVM__gamma':np.logspace(-9, -3, 6)
}
create_grid=GridSearchCV(pipeline3, check_params3,cv=8, scoring='f1_micro', verbose=2)
create_grid.fit(train,y)
print("Best fit")
#print(cross_values.mean())
#print(cross_values)
print(create_grid.best_params_)
print(create_grid.best_score_)
# Out:
# Fitting 8 folds for each of 20 candidates, totalling 160 fits
# [CV] SVM__C=0.101 ....................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..................................... SVM__C=0.101, total=   1.6s
# [CV] SVM__C=0.101 ....................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV] ..................................... SVM__C=0.101, total=   1.6s
# [CV] SVM__C=0.101 ....................................................
# [CV] ..................................... SVM__C=0.101, total=   1.6s
# [CV] SVM__C=0.101 ....................................................
# [CV] ..................................... SVM__C=0.101, total=   1.7s
# [CV] SVM__C=0.101 ....................................................
# [CV] ..................................... SVM__C=0.101, total=   1.6s
# ...

# %%
row=np.array(dataset.iloc[447].drop(columns='labels'))
signal=row[~np.isnan(row)]
bio = nk.bio_process(ecg=signal, sampling_rate=300)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
plt.plot(bio['df'][0:1000].ECG_Filtered)
#plt.plot(signal[0:1500])
plt.scatter(bio['ECG']['R_Peaks'][0:3],bio['df'].ECG_Filtered.iloc[bio['ECG']['R_Peaks']][0:3],color='blue')
plt.scatter(bio['ECG']['Q_Waves'][0:3],bio['df'].ECG_Filtered.iloc[bio['ECG']['Q_Waves']][0:3],color='purple')
plt.scatter(bio['ECG']['Q_Waves_Onsets'][0:3],bio['df'].ECG_Filtered.iloc[bio['ECG']['Q_Waves_Onsets']][0:3],color='green')

#plt.scatter(bio2['ECG']['T_Waves'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves']][0:3],color='green')
#plt.scatter(bio2['ECG']['T_Waves_Onsets'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves_Onsets']][0:3],color='red')
#plt.scatter(bio2['ECG']['T_Waves_Ends'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['T_Waves_Ends']][0:3],color='grey')

plt.scatter(bio['ECG']['P_Waves'][0:3],bio['df'].ECG_Filtered.iloc[bio['ECG']['P_Waves']][0:3],color='orange')
#plt.scatter(bio2['ECG']['S_Waves'][0:3],bio2['df'].ECG_Filtered.iloc[bio2['ECG']['S_Waves']][0:3],color='yellow')

# %%
null_data = new_df[new_df.isnull().any(axis=1)]
null_data
# Out:
#          bpm_avg     bpm_sd     bpm_med      bpm_mn     bpm_max       P_avg  \
# 447    95.008057   1.431391   94.736842   93.264249   98.901099   66.875974
# 1151   51.358872   1.102907   50.991501   49.046322   53.412463   99.391245
# 1940   86.371103   1.354371   86.124402   83.720930   88.235294  136.206731
# 2409   80.215017   0.953853   80.000000   77.922078   82.191781  392.376952
# 3035   65.667076   4.825272   65.217391   51.724138   87.378641  165.328681
# 3639   84.153118  28.755423   73.469388   72.289157  189.473684  109.580605
# 4157  125.496872   2.213677  125.437063  120.000000  129.496403   32.951173
#
#           P_std       Q_avg      Q_std       R_avg       R_std  S_avg  S_std  \
# 447    6.737200 -413.964248  39.569159  359.586250   49.361571    NaN    NaN
# 1151  18.347982 -631.922442  34.918650  408.140747   41.039981    NaN    NaN
# 1940  25.212231 -618.290744  78.514125  316.826516   59.904296    NaN    NaN
# ...

# %% [markdown]
# ## model

# %%
#Best fit
#{'SVM__C': 0.101, 'SVM__coef0': 1, 'SVM__degree': 3}
#0.6841384705652259



scaler = StandardScaler().fit(train)
train_ = scaler.transform(train)



clf = svm.SVC(kernel = 'poly', gamma='scale', degree= 3, coef0= 1,
                decision_function_shape='ovo', C = 0.101,
                cache_size=3000, random_state = 42,
                class_weight = 'balanced')

clf.fit(train_, y)
# Out:
# SVC(C=0.101, cache_size=3000, class_weight='balanced', coef0=1,
#     decision_function_shape='ovo', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)

# %% [markdown]
# ## Testing

# %%
#test_data = pd.read_csv('/Users/Cristy/Downloads/task3/X_test.csv')
#test_data=test_data.drop(columns='id')

for i in range(2898,test_data.shape[0]):
    row=test_data.iloc[i]
    feats=extract_features(np.array(row.drop(columns='labels')))
    bpm_av.append(feats['bpm_avg'])
    bpm_sd.append(feats['bpm_std'])  
    bpm_md.append(feats['bpm_med']) 
    bpm_mn.append(feats['bpm_min'])  
    bpm_mx.append(feats['bpm_max'])  
    P_av.append(feats['P_avg']) 
    P_sd.append(feats['P_std']) 
    Q_av.append(feats['Q_avg']) 
    Q_sd.append(feats['Q_std']) 
    R_av.append(feats['R_avg']) 
    R_sd.append(feats['R_std']) 
    print(i)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# 2898
# /Users/Cristy/.virtualenvs/myenv/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
# Error 844, 1279,2897


#total: 3411 obs (5113 in training data)
len(S_sd)
# Out:
# 5113

# %%
S_sd[5112]
# Out:
# 59.26570357933837

# %%
bpm_av2= bpm_av[5113:]
bpm_sd2=bpm_sd[5113:]
bpm_md2=bpm_md[5113:]
bpm_mn2=bpm_mn[5113:]
bpm_mx2=bpm_mx[5113:]
P_av2=P_av[5113:]
P_sd2=P_sd[5113:]
Q_av2=Q_av[5113:]
Q_sd2=Q_sd[5113:]
R_av2=R_av[5113:]
R_sd2=R_sd[5113:]

new_test=pd.DataFrame({'bpm_avg':pd.Series(bpm_av2),'bpm_sd':pd.Series(bpm_sd2),'bpm_med':pd.Series(bpm_md2),\
              'bpm_mn':pd.Series(bpm_mn2),'bpm_max':pd.Series(bpm_mx2),\
              'P_avg':pd.Series(P_av2),'P_std':pd.Series(P_sd2),'Q_avg':pd.Series(Q_av2),'Q_std':pd.Series(Q_sd2),\
              'R_avg':pd.Series(R_av2),'R_std':pd.Series(R_sd2)})

# %%
new_test.head()
# Out:
#       bpm_avg     bpm_sd    bpm_med     bpm_mn     bpm_max       P_avg  \
# 0   70.492320   4.479050  71.717701  61.643836   75.949367   83.695617
# 1   56.143222   4.051028  55.901160  48.517520   69.498069   27.587309
# 2  108.154220  77.279991  69.230769  47.745358  315.789474  122.835308
# 3   62.196559   1.128303  62.068966  60.200669   64.748201   27.876714
# 4   60.744768   3.295398  60.000000  56.426332   68.181818   47.122918
#
#         P_std       Q_avg       Q_std        R_avg       R_std
# 0   37.257751 -242.746503   47.492699  1051.642162  107.597292
# 1    7.254125 -164.095260   13.550646   741.348021   43.575812
# 2  135.010725 -194.824444  209.547073   439.964092  189.068941
# 3   15.221679 -107.091910   10.643287   401.413925   21.689511
# 4   13.296199 -200.279568   18.404909   821.503208   38.233515

# %%
test_ = scaler.transform(new_test)
test_y = clf.predict(test_)
file_test = "ecg_svm_poly"

# %%
test_y
# Out:
# array([0, 2, 3, ..., 0, 0, 1])

# %%
# Out:
# 0

# %%
def Insert_row_(row_number, df, row_value): 
    # Slice the upper half of the dataframe 
    df1 = df[0:row_number] 
   
    # Store the result of lower half of the dataframe 
    df2 = df[row_number:] 
   
    # Inser the row in the upper half dataframe 
    df1.loc[row_number]=row_value 
   
    # Concat the two dataframes 
    df_result = pd.concat([df1, df2]) 
   
    # Reassign the index labels 
    df_result.index = [*range(df_result.shape[0])] 
   
    # Return the updated dataframe 
    return df_result 

#844, 1279,2897
test_ys=pd.Series(test_y)
test_y2=Insert_row_(844,test_ys,1)
test_y2=Insert_row_(1279,test_y2,2)
test_y2=Insert_row_(2897,test_y2,3)
len(test_y2)
# Out:
# 3411

# %%
test_y2
# Out:
# 0       0
# 1       2
# 2       3
# 3       0
# 4       0
#        ..
# 3406    3
# 3407    0
# 3408    0
# 3409    0
# 3410    1
# Length: 3411, dtype: int64

# %%
output = pd.DataFrame({'id':[float(i) for i in range(0,len(test_y2))],'y':test_y2})
output.to_csv("{}.csv".format(file_test),index=False)
